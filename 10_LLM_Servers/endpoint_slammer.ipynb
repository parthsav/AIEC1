# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/psavani-us-3wpxe9x8g/deployments/hchnk9t1"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# The classic “answer” that gets quoted most often comes from a tongue‑twister‑style bit of folklore:
#
# > **A woodchuck could chuck about 700 lb (≈ 300 kg) of wood** – roughly a quarter of a cord.
#
# (That figure comes from a (somewhat tongue‑in‑cheek) estimate made by a wildlife expert a few decades ago.)
#
# In reality, of course, a woodchuck – i.e., a groundhog – can’t actually “chuck” wood at all; they’re busy munching on clover and digging burrows. But if they could, the 700‑lb figure is the whimsical answer the old rhyme usually lands on.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 11: The classic answer is a tongue‑twister itself:
#
# > *A woodchu...
# Response 21: A woodchuck would chuck **as much wood as a woodchuck could ...
# Response 22: The classic tongue‑twister has no “real” answer—it’s really ...
# Response 15: The classic answer to that tongue‑twister is:
#
# *“As much woo...
# Response 18: The classic “tongue‑twister” answer is:
#
# > “A woodchuck woul...
# Response 13: The classic “answer” to the old tongue‑twister is really jus...
# Response 5: A wood‑chuck would “chuck” as much wood as a wood‑chuck can ...
# Response 24: The classic answer is a tongue‑in‑cheek one: a woodchuck wou...
# Response 19: A woodchuck would chuck *as much wood as a woodchuck could* ...
# Response 7: The classic tongue‑twister is really just a silly play on wo...
# Response 12: The old tongue‑twister is really just a playful loop, so the...
# Response 8: The classic tongue‑twister doesn’t have a literal answer – i...
# Response 17: The classic tongue‑twister answer is:
#
# > “A woodchuck would ...
# Response 23: The classic punchline is self‑referential: **“As much wood a...
# Response 1: The classic answer is really just the tongue‑twister itself:...
# Response 10: The classic punch‑line to that tongue‑twister is:
#
# **“A wood...
# Response 4: It’s a classic tongue‑twister, so the “real” answer is just ...
# Response 9: It’s a classic tongue‑twister, so the “real” answer is reall...
# Response 3: The classic tongue‑twister answer is:
#
# > “As much wood as a ...
# Response 14: The classic “tongue‑twister” answer is a play on the wording...
# Response 20: **Answer (Request 20):**
# The classic tongue‑twister answer...
# Response 6: The classic “wood‑chuck” tongue‑twister is really just a pla...
# Response 2: The classic response to the tongue‑twister is really just th...
# Response 16: The classic “tongue‑twister” answer is: *“As much wood as a ...
